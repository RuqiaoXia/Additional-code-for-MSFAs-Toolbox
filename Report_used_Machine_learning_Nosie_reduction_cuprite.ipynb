# %% [markdown]
# # This notebook shows the optimization to find the best spectral bands for unmixing a set of endmember spectra from a hyperspectral cube.

# %%
# %pylab inline
from pysptools import abundance_maps
import random
import pandas as pd
import urllib
import itertools
from scipy.io import loadmat
from scipy.signal import convolve2d
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
dataset = "cuprite"

d = loadmat("../input/reference-datasets/" + dataset + "/" + dataset + ".mat")
em = loadmat("../input/reference-datasets/" + dataset + "/endmembers/endmembers.mat")
dinfo = pd.read_csv("../input/reference-datasets/" + dataset + "/info.csv",header=None,index_col=None,names=["parameter",'value','unit'])

nrow = int(dinfo[dinfo['parameter'] == 'nrow'].value.values[0])
ncol = int(dinfo[dinfo['parameter'] == 'ncol'].value.values[0])

nbands = int(dinfo[dinfo['parameter'] == 'nbands'].value.values[0])
spec_start = dinfo[dinfo['parameter'] == 'spec_start'].value.values[0]
spec_end = dinfo[dinfo['parameter'] == 'spec_end'].value.values[0]

data = d['Y']
data = data / data.max()
try:
    spec_bands = d['SlectBands'].flatten()
except:
    spec_bands = arange(0,nbands)

# Define wavelength array
wavelength = linspace(spec_start,spec_end,nbands)
wavelength = wavelength[spec_bands]

if len(em['M']) > len(wavelength):
    endmembers = em['M'][spec_bands]
else:
    endmembers = em['M']

endmembers = endmembers.reshape(len(wavelength),-1)

a_map = em["A"].reshape((endmembers.shape[1],nrow,ncol)).T

hypercube = data.copy()
spectra = endmembers.T
hypercube = hypercube.reshape(len(wavelength), a_map.shape[1], a_map.shape[0]).T

figure(1)
plot(wavelength, spectra[0])
plot(wavelength, spectra[1])
plot(wavelength, spectra[2])
plot(wavelength, spectra[3])
plot(wavelength, spectra[4])
plot(wavelength, spectra[5])
plot(wavelength, spectra[6])
plot(wavelength, spectra[7])
plot(wavelength, spectra[8])
plot(wavelength, spectra[9])
plot(wavelength, spectra[10])
plot(wavelength, spectra[11])
plt.show()

'cut it first, my computer cannot run the whole dataset, need to used online GPU'

# upper left corner
area_1 = hypercube[:20,:20,:]
map_1 = a_map[:20,:20,:]

#centre
area_2 = hypercube[100:120,100:120,:]
map_2 = a_map[:20,:20,:]

#endmember 6
area_3 = hypercube[100:120,130:150,:]
map_3 = a_map[100:120,130:150,:]

#endmember 7
area_4 = hypercube[230:250,100:120,:]
map_4 = a_map[230:250,100:120,:]


data_1 = np.append(area_1, area_2,axis = 0)
data_map_1 = np.append(map_1, map_2, axis = 0)

data_2 = np.append(area_3, area_4,axis = 0)
data_map_2 = np.append(map_3, map_4, axis = 0)

hypercube = np.append(data_1, data_2,axis = 1)
a_map = np.append(data_map_1, data_map_2,axis = 1)

# %%
def create_hypercube(a_map, spectra):
 
    '''
    Generate a hypercube.
    
    Inputs:
        a_map (N*M, L)
             
        spectra (L x Q array) - Array of 1D spectral respones for each pixel. Number of array members
            should be equal to the maximum value in im (L). Q is sample points in wavelength space.        
    
    N represents N*M!
    
    Output:
        hypercube (N*M, Q)
    '''

    N,_ = a_map.shape
    L,Q = spectra.shape

    hypercube = zeros((N,Q))
    
    for i in range(L):
        hypercube += outer(a_map[:,i],spectra[i]).reshape((N,Q))
    
    return hypercube

# %%
def pre_processing(hypercube, abundance_map, endmembers, wavelength, center_wavelengths, bandwidths, return_predicted=False):
    '''
    Function to compute unmixing accuracy using NNLS spectral unmixing given a set of spectral band 
    center wavelengths and bandwidths. Assuming gaussian filter responses with a bandwidth defined
    as the FWHM.
    
    Inputs:
        hypercube (N X M x Q) - 3D synthetic hypercube.
        
        abundance_map (N x M x P)- 3D ground-truth abundance map of target. Each channel in L corresponds to the
             abundance (between 0 and 1) of the spectral signature in the spectra array. 
        
        endmembers (P x Q array) - Array of endmember signals to unmix.
        
        wavelength (1 x Q array) - Array describing the wavelength value corresponding to the spectral
            response arrays.
        
        center_wavelengths (1 x L array) - Array or list of center wavelengths for Gaussian filter responses
            to use for unmixing.
        
        bandwidths (1 x L array) - Array or list of bandwidths for Gaussian filter responses
            to use for unmixing.
        
    Outputs:
        accuracy (float) - RMS error of the unmixed abundance compared to the gruond truth
        
        
    '''
    # Extract relevant dimensions
    N,M,Q = hypercube.shape
    
    # Define filter responses
    filters = [exp(-(wavelength - center_wavelengths[i])**2 / (2*(bandwidths[i]/2.355)**2)) for i in range(len(center_wavelengths))]
    
    P = len(endmembers)
    L = len(filters)
    
    # Pre-allocate arrays
    data_sig = zeros((N*M,L))
    endmember_sig = zeros((P,L))
    
    # Iterate through each filter
    for i,f in enumerate(filters):
        # Compute the signal from each filter received from the data
        # and that received from an endmember.
        data_sig[:,i] = sum(hypercube.reshape((N*M,Q))*f,axis=1) # (N*M) x L
        
        for j, e in enumerate(endmembers):
            endmember_sig[j,i] = sum(endmembers[j]*f) # P x Q
            
    # Reshape the data array into 1d array,predicted_a_map
    predicted = abundance_maps.amaps.NNLS(data_sig, endmember_sig) # (N*M x P)

    # generate hypercube by predicted abundance map
    x = create_hypercube(predicted, endmembers)
    y_reshape = abundance_map.reshape((N*M,len(endmember_sig)))
    y = create_hypercube(y_reshape, endmembers)
    
    # Take rms.
    acc = x - y
    accuracy = sqrt(mean(acc**2))


    return accuracy, x, y,predicted,y_reshape

# %% [markdown]
# x is the predicted
# y is the ground truth

# %% [markdown]
# #  Set 1

# %%
center_wavelengths = [2038., 2238. ,1278. , 918.  ,438., 1758. ,1438. ,1958., 1398., 2278. , 558. ,1118.]

# %%
bandwidths = [20,20,20,
             20,20,20,
              20,20,20,
              20,20,20
             ]

# %%
acc, X_predicted, X_groud_truth,Y_predicted, Y_groud_truth = pre_processing(hypercube, a_map, spectra,wavelength, center_wavelengths, bandwidths, return_predicted=False)

# %%
acc
# Out:
# 0.010377339650686466

# %%
X_predicted.shape
# Out:
# (1600, 188)

# %%
Y_predicted.shape
# Out:
# (1600, 12)

# %% [markdown]
# # Start ML Bolck

# %%
from sklearn.metrics import accuracy_score
from sklearn.model_selection import train_test_split


import tensorflow as tf
from keras import layers
from keras import models

# %%
X_predicted_half,X2_predicted_half,Y_predicted_half,Y2_predicted_half = train_test_split(X_predicted, Y_predicted, test_size=0.5)

# %%
x_train = np.vstack((X_predicted_half,X_groud_truth))

# %%
Y_predicted_half.shape
# Out:
# (800, 12)

# %%
Y_groud_truth.shape
# Out:
# (1600, 12)

# %%
y_train = np.vstack((Y_predicted_half,Y_groud_truth))

# %%
x_test = X2_predicted_half

# %%
y_test = Y2_predicted_half

# %%
x_train.shape
# Out:
# (2400, 188)

# %%
y_train.shape
# Out:
# (2400, 12)

# %%
x_test.shape
# Out:
# (800, 188)

# %%
y_test.shape
# Out:
# (800, 12)

# %%
#savetxt("../Machine_Learning_ref_data/x.txt",X)

# %%
#savetxt("../Machine_Learning_ref_data/y.txt",Y)

# %%
def get_compiled_model():
    model = tf.keras.Sequential([
    tf.keras.layers.Dense(256, activation='relu'),
    tf.keras.layers.Dense(32, activation='relu'),
    tf.keras.layers.Dense(128, activation='relu'),
    tf.keras.layers.Dropout(0.1),
    tf.keras.layers.Dense(16, activation='relu'),
    
    tf.keras.layers.Dense(12,'softmax')
  ])

    model.compile(optimizer='adam',
                loss=tf.keras.losses.BinaryCrossentropy(from_logits=True),
                metrics=['accuracy'])
    return model

# %%
model = get_compiled_model()

# %%
history = model.fit(x_train,y_train, epochs=50)
# Out:
# Epoch 1/50
# 75/75 [==============================] - 0s 898us/step - loss: 0.7348 - accuracy: 0.4117
# Epoch 2/50
# 75/75 [==============================] - 0s 867us/step - loss: 0.7347 - accuracy: 0.4929
# Epoch 3/50
# 75/75 [==============================] - 0s 805us/step - loss: 0.7345 - accuracy: 0.6383
# Epoch 4/50
# 75/75 [==============================] - 0s 760us/step - loss: 0.7344 - accuracy: 0.6792
# Epoch 5/50
# 75/75 [==============================] - 0s 799us/step - loss: 0.7344 - accuracy: 0.7258
# Epoch 6/50
# 75/75 [==============================] - 0s 867us/step - loss: 0.7344 - accuracy: 0.8179
# Epoch 7/50
# 75/75 [==============================] - 0s 784us/step - loss: 0.7344 - accuracy: 0.8379
# Epoch 8/50
# 75/75 [==============================] - 0s 770us/step - loss: 0.7343 - accuracy: 0.8525
# Epoch 9/50
# 75/75 [==============================] - 0s 850us/step - loss: 0.7343 - accuracy: 0.8479
# Epoch 10/50
# 75/75 [==============================] - 0s 793us/step - loss: 0.7343 - accuracy: 0.8537
# Epoch 11/50
# 75/75 [==============================] - 0s 800us/step - loss: 0.7343 - accuracy: 0.8579
# Epoch 12/50
# 75/75 [==============================] - 0s 832us/step - loss: 0.7343 - accuracy: 0.8637
# Epoch 13/50
# 75/75 [==============================] - 0s 833us/step - loss: 0.7343 - accuracy: 0.8550
# Epoch 14/50
# 75/75 [==============================] - 0s 814us/step - loss: 0.7343 - accuracy: 0.8571
# Epoch 15/50
# 75/75 [==============================] - 0s 784us/step - loss: 0.7343 - accuracy: 0.8600
# Epoch 16/50
# 75/75 [==============================] - 0s 787us/step - loss: 0.7343 - accuracy: 0.8671
# Epoch 17/50
# 75/75 [==============================] - 0s 875us/step - loss: 0.7343 - accuracy: 0.8629
# Epoch 18/50
# 75/75 [==============================] - 0s 826us/step - loss: 0.7343 - accuracy: 0.8654
# Epoch 19/50
# 75/75 [==============================] - 0s 959us/step - loss: 0.7343 - accuracy: 0.8717
# Epoch 20/50
# 75/75 [==============================] - 0s 949us/step - loss: 0.7343 - accuracy: 0.8779
# Epoch 21/50
# 75/75 [==============================] - 0s 947us/step - loss: 0.7343 - accuracy: 0.8692
# Epoch 22/50
# 75/75 [==============================] - 0s 1ms/step - loss: 0.7343 - accuracy: 0.8796
# Epoch 23/50
# 75/75 [==============================] - 0s 1ms/step - loss: 0.7343 - accuracy: 0.8729
# Epoch 24/50
# 75/75 [==============================] - 0s 961us/step - loss: 0.7343 - accuracy: 0.8813
# Epoch 25/50
# 75/75 [==============================] - 0s 932us/step - loss: 0.7343 - accuracy: 0.8846
# Epoch 26/50
# 75/75 [==============================] - 0s 903us/step - loss: 0.7343 - accuracy: 0.8729
# Epoch 27/50
# 75/75 [==============================] - 0s 879us/step - loss: 0.7343 - accuracy: 0.8883
# Epoch 28/50
# 75/75 [==============================] - 0s 959us/step - loss: 0.7343 - accuracy: 0.8792
# Epoch 29/50
# 75/75 [==============================] - 0s 1ms/step - loss: 0.7343 - accuracy: 0.8946
# Epoch 30/50
# 75/75 [==============================] - 0s 1ms/step - loss: 0.7343 - accuracy: 0.8933
# Epoch 31/50
# 75/75 [==============================] - 0s 853us/step - loss: 0.7343 - accuracy: 0.8938
# Epoch 32/50
# 75/75 [==============================] - 0s 787us/step - loss: 0.7343 - accuracy: 0.8900
# Epoch 33/50
# 75/75 [==============================] - 0s 909us/step - loss: 0.7343 - accuracy: 0.8942
# Epoch 34/50
# 75/75 [==============================] - 0s 897us/step - loss: 0.7343 - accuracy: 0.8763
# Epoch 35/50
# 75/75 [==============================] - 0s 891us/step - loss: 0.7343 - accuracy: 0.8971
# Epoch 36/50
# 75/75 [==============================] - 0s 901us/step - loss: 0.7343 - accuracy: 0.9038
# Epoch 37/50
# 75/75 [==============================] - 0s 941us/step - loss: 0.7343 - accuracy: 0.9071
# Epoch 38/50
# 75/75 [==============================] - 0s 842us/step - loss: 0.7343 - accuracy: 0.9075
# Epoch 39/50
# 75/75 [==============================] - 0s 864us/step - loss: 0.7343 - accuracy: 0.8950
# Epoch 40/50
# 75/75 [==============================] - 0s 849us/step - loss: 0.7343 - accuracy: 0.9087
# Epoch 41/50
# 75/75 [==============================] - 0s 775us/step - loss: 0.7343 - accuracy: 0.8967
# Epoch 42/50
# 75/75 [==============================] - 0s 939us/step - loss: 0.7343 - accuracy: 0.9000
# Epoch 43/50
# 75/75 [==============================] - 0s 963us/step - loss: 0.7343 - accuracy: 0.8967
# Epoch 44/50
# 75/75 [==============================] - 0s 971us/step - loss: 0.7343 - accuracy: 0.9000
# Epoch 45/50
# 75/75 [==============================] - 0s 976us/step - loss: 0.7343 - accuracy: 0.9112
# Epoch 46/50
# 75/75 [==============================] - 0s 1ms/step - loss: 0.7343 - accuracy: 0.8983
# Epoch 47/50
# 75/75 [==============================] - 0s 999us/step - loss: 0.7343 - accuracy: 0.9067
# Epoch 48/50
# 75/75 [==============================] - 0s 975us/step - loss: 0.7343 - accuracy: 0.9067
# Epoch 49/50
# 75/75 [==============================] - 0s 981us/step - loss: 0.7343 - accuracy: 0.9200
# Epoch 50/50
# 75/75 [==============================] - 0s 961us/step - loss: 0.7343 - accuracy: 0.9142

# %%
loss,acc = model.evaluate(x_test,y_test, verbose=1)
# Out:
# 25/25 [==============================] - 0s 571us/step - loss: 0.7342 - accuracy: 0.9000

# %%
print(loss,acc)
# Out:
# 0.7342137694358826 0.8999999761581421

# %%
#model.save('my_model_amazing_acc_0.99.h5')

# %%
# model=load_model("my_model_.hdf5")

# %%
training_loss = history.history['loss']

# %%
training_acc = history.history['accuracy']

# %%
plot(training_acc)

# %% [markdown]
# #  Set 2

# %%
center_wavelengths = [2402, 2016, 1920, 2094, 2008, 1046, 470, 680, 1398, 1698, 1230, 896.]

# %%
bandwidths = [20,20,20,
             20,20,20,
              20,20,20,
              20,20,20
             ]

# %%
acc, X_predicted, X_groud_truth,Y_predicted, Y_groud_truth = pre_processing(hypercube, a_map, spectra,wavelength, center_wavelengths, bandwidths, return_predicted=False)

# %%
acc
# Out:
# 0.0107177342809525

# %%
X_predicted.shape
# Out:
# (1600, 188)

# %%
Y_predicted.shape
# Out:
# (1600, 12)

# %% [markdown]
# # Start ML Bolck

# %%
X_predicted_half,X2_predicted_half,Y_predicted_half,Y2_predicted_half = train_test_split(X_predicted, Y_predicted, test_size=0.5)

# %%
x_train = np.vstack((X_predicted_half,X_groud_truth))

# %%
Y_predicted_half.shape
# Out:
# (800, 12)

# %%
Y_groud_truth.shape
# Out:
# (1600, 12)

# %%
y_train = np.vstack((Y_predicted_half,Y_groud_truth))

# %%
x_test = X2_predicted_half

# %%
y_test = Y2_predicted_half

# %%
x_train.shape
# Out:
# (2400, 188)

# %%
y_train.shape
# Out:
# (2400, 12)

# %%
x_test.shape
# Out:
# (800, 188)

# %%
y_test.shape
# Out:
# (800, 12)

# %%
#savetxt("../Machine_Learning_ref_data/x.txt",X)

# %%
#savetxt("../Machine_Learning_ref_data/y.txt",Y)

# %%
def get_compiled_model():
    model = tf.keras.Sequential([
    tf.keras.layers.Dense(256, activation='relu'),
    tf.keras.layers.Dense(32, activation='relu'),
    tf.keras.layers.Dense(128, activation='relu'),
    tf.keras.layers.Dropout(0.1),
    tf.keras.layers.Dense(16, activation='relu'),
    
    tf.keras.layers.Dense(12,'softmax')
  ])

    model.compile(optimizer='adam',
                loss=tf.keras.losses.BinaryCrossentropy(from_logits=True),
                metrics=['accuracy'])
    return model

# %%
model = get_compiled_model()

# %%
history = model.fit(x_train,y_train, epochs=50)
# Out:
# Epoch 1/50
# 75/75 [==============================] - 0s 876us/step - loss: 0.7348 - accuracy: 0.4104
# Epoch 2/50
# 75/75 [==============================] - 0s 874us/step - loss: 0.7347 - accuracy: 0.5000
# Epoch 3/50
# 75/75 [==============================] - 0s 865us/step - loss: 0.7345 - accuracy: 0.6179
# Epoch 4/50
# 75/75 [==============================] - 0s 865us/step - loss: 0.7345 - accuracy: 0.6637
# Epoch 5/50
# 75/75 [==============================] - 0s 850us/step - loss: 0.7345 - accuracy: 0.6662
# Epoch 6/50
# 75/75 [==============================] - 0s 796us/step - loss: 0.7345 - accuracy: 0.6658
# Epoch 7/50
# 75/75 [==============================] - 0s 786us/step - loss: 0.7344 - accuracy: 0.6913
# Epoch 8/50
# 75/75 [==============================] - 0s 862us/step - loss: 0.7344 - accuracy: 0.7713
# Epoch 9/50
# 75/75 [==============================] - 0s 840us/step - loss: 0.7344 - accuracy: 0.8200
# Epoch 10/50
# 75/75 [==============================] - 0s 817us/step - loss: 0.7344 - accuracy: 0.8371
# Epoch 11/50
# 75/75 [==============================] - 0s 820us/step - loss: 0.7344 - accuracy: 0.8492
# Epoch 12/50
# 75/75 [==============================] - 0s 830us/step - loss: 0.7344 - accuracy: 0.8496
# Epoch 13/50
# 75/75 [==============================] - 0s 814us/step - loss: 0.7344 - accuracy: 0.8375
# Epoch 14/50
# 75/75 [==============================] - 0s 780us/step - loss: 0.7344 - accuracy: 0.8417
# Epoch 15/50
# 75/75 [==============================] - 0s 800us/step - loss: 0.7344 - accuracy: 0.8608
# Epoch 16/50
# 75/75 [==============================] - 0s 854us/step - loss: 0.7344 - accuracy: 0.8517
# Epoch 17/50
# 75/75 [==============================] - 0s 813us/step - loss: 0.7344 - accuracy: 0.8508
# Epoch 18/50
# 75/75 [==============================] - 0s 826us/step - loss: 0.7344 - accuracy: 0.8600
# Epoch 19/50
# 75/75 [==============================] - 0s 763us/step - loss: 0.7343 - accuracy: 0.8596
# Epoch 20/50
# 75/75 [==============================] - 0s 1ms/step - loss: 0.7343 - accuracy: 0.8704
# Epoch 21/50
# 75/75 [==============================] - 0s 883us/step - loss: 0.7343 - accuracy: 0.8579
# Epoch 22/50
# 75/75 [==============================] - 0s 929us/step - loss: 0.7343 - accuracy: 0.8625
# Epoch 23/50
# 75/75 [==============================] - 0s 859us/step - loss: 0.7343 - accuracy: 0.8592
# Epoch 24/50
# 75/75 [==============================] - 0s 1ms/step - loss: 0.7343 - accuracy: 0.8642
# Epoch 25/50
# 75/75 [==============================] - 0s 1ms/step - loss: 0.7343 - accuracy: 0.8750
# Epoch 26/50
# 75/75 [==============================] - 0s 989us/step - loss: 0.7343 - accuracy: 0.8704
# Epoch 27/50
# 75/75 [==============================] - 0s 846us/step - loss: 0.7343 - accuracy: 0.8758
# Epoch 28/50
# 75/75 [==============================] - 0s 856us/step - loss: 0.7343 - accuracy: 0.8650
# Epoch 29/50
# 75/75 [==============================] - 0s 885us/step - loss: 0.7343 - accuracy: 0.8742
# Epoch 30/50
# 75/75 [==============================] - 0s 1ms/step - loss: 0.7343 - accuracy: 0.8779
# Epoch 31/50
# 75/75 [==============================] - 0s 1ms/step - loss: 0.7343 - accuracy: 0.8833
# Epoch 32/50
# 75/75 [==============================] - 0s 1ms/step - loss: 0.7343 - accuracy: 0.8683
# Epoch 33/50
# 75/75 [==============================] - 0s 991us/step - loss: 0.7343 - accuracy: 0.8825
# Epoch 34/50
# 75/75 [==============================] - 0s 863us/step - loss: 0.7343 - accuracy: 0.8712
# Epoch 35/50
# 75/75 [==============================] - 0s 946us/step - loss: 0.7343 - accuracy: 0.8763
# Epoch 36/50
# 75/75 [==============================] - 0s 1ms/step - loss: 0.7343 - accuracy: 0.8792
# Epoch 37/50
# 75/75 [==============================] - 0s 1ms/step - loss: 0.7343 - accuracy: 0.8846
# Epoch 38/50
# 75/75 [==============================] - 0s 1ms/step - loss: 0.7343 - accuracy: 0.8817
# Epoch 39/50
# 75/75 [==============================] - 0s 1ms/step - loss: 0.7343 - accuracy: 0.8879
# Epoch 40/50
# 75/75 [==============================] - 0s 963us/step - loss: 0.7343 - accuracy: 0.8808
# Epoch 41/50
# 75/75 [==============================] - 0s 958us/step - loss: 0.7343 - accuracy: 0.8863
# Epoch 42/50
# 75/75 [==============================] - 0s 941us/step - loss: 0.7343 - accuracy: 0.8867
# Epoch 43/50
# 75/75 [==============================] - 0s 964us/step - loss: 0.7343 - accuracy: 0.8917
# Epoch 44/50
# 75/75 [==============================] - 0s 890us/step - loss: 0.7343 - accuracy: 0.8871
# Epoch 45/50
# 75/75 [==============================] - 0s 909us/step - loss: 0.7343 - accuracy: 0.8913
# Epoch 46/50
# 75/75 [==============================] - 0s 959us/step - loss: 0.7343 - accuracy: 0.8946
# Epoch 47/50
# 75/75 [==============================] - 0s 1ms/step - loss: 0.7343 - accuracy: 0.8829
# Epoch 48/50
# 75/75 [==============================] - 0s 926us/step - loss: 0.7343 - accuracy: 0.8867
# Epoch 49/50
# 75/75 [==============================] - 0s 1ms/step - loss: 0.7343 - accuracy: 0.8871
# Epoch 50/50
# 75/75 [==============================] - 0s 949us/step - loss: 0.7343 - accuracy: 0.8933

# %%
loss,acc = model.evaluate(x_test,y_test, verbose=1)
# Out:
# 25/25 [==============================] - 0s 728us/step - loss: 0.7343 - accuracy: 0.8850

# %%
print(loss,acc)
# Out:
# 0.7342867255210876 0.8849999904632568

# %%
#model.save('my_model_amazing_acc_0.99.h5')

# %%
# model=load_model("my_model_.hdf5")

# %%
training_loss_2 = history.history['loss']

# %%
training_acc_2 = history.history['accuracy']

# %%
x_axis = range(1,51)

# %%
plot(x_axis,training_acc_2)

# %%
plot(x_axis,training_acc_2,'blue')
plot(x_axis,training_acc,'red')
