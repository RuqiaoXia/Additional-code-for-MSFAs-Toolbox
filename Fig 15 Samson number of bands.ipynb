# %%
# %pylab inline
from pysptools import abundance_maps
import numpy
from random import sample as randsamp
import pandas as pd

import random
import urllib
import itertools
from scipy.io import loadmat
from scipy.signal import convolve2d

number = [1,2,3,4,5,6]
time = [127.25,149.08,176.68,227.28,257.57,315.74]
rmse = [0.412,0.162, 0.162,0.161,0.161,0.161]
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
fig = plt.figure()
ax = fig.add_subplot(111)
ax.plot(number, rmse,'-xb', label = 'RMSE')
ax.legend(loc=2)
ax.grid()
ax2 = ax.twinx()
ax2.plot(number, time,'-xr', label = 'time')
ax2.legend(loc=1)

ax.set_xlabel("Number of bands",fontsize=15)
ax.set_ylabel(r"RMSE",fontsize=15)
ax2.set_ylabel(r"Time(sec)",fontsize=15)
ax2.set_ylim(0, 400)
ax.set_ylim(0,0.5)
ax2.legend(loc=1)

title('Samson',fontsize=15)
# Out:
# Text(0.5, 1.0, 'Samson')
